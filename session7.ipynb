# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,1,100)
def exp_function(x):
    return np.exp(x)

y = exp_function(x)

plt.plot(x,y)
plt.xlabel('Time = [milliseconds]')
plt.ylabel('Awesomeness')
plt.title('Plot of exp(x) from 0 to 1')
plt.savefig('exp_plot.pdf', format='pdf')
